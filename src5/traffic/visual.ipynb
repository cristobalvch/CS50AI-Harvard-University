# %%
import cv2
import numpy as np
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from IPython.display import clear_output

# %%
images = []
labels = []
EPOCHS = 10
IMG_WIDTH = 30
IMG_HEIGHT = 30
NUM_CATEGORIES = 43

# %%
for folder in os.listdir('gtsrb'):
    path_folder = os.path.join('gtsrb',folder)

    for filename in os.listdir(path_folder):
        image_bgr = cv2.imread(file_path,cv2.IMREAD_COLOR)
        resize_img = cv2.resize(image_bgr,(30,30))
        
        images.append(resize_img)
        labels.append(int(folder))
    print("uploading data..")
    clear_output(wait=True)

labels = tf.keras.utils.to_categorical(labels)
x_train, x_test, y_train, y_test = train_test_split(np.array(images), np.array(labels), test_size=0.4)

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(IMG_WIDTH,IMG_HEIGHT,3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(500,activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(NUM_CATEGORIES,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train,y_train,epochs = 10)
model.evaluate(x_test,y_test,verbose=2)
# Out:
# Epoch 1/10
# 500/500 [==============================] - 37s 73ms/step - loss: 4.5054 - accuracy: 0.0489
# Epoch 2/10
# 500/500 [==============================] - 39s 78ms/step - loss: 3.5224 - accuracy: 0.0547
# Epoch 3/10
# 376/500 [=====================&gt;........] - ETA: 10s - loss: 3.5200 - accuracy: 0.0562ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# &lt;ipython-input-132-ed447652fed8&gt; in &lt;module&gt;
#      27
# ---&gt; 28 model.fit(x_train,y_train,epochs = 10)
#      29 model.evaluate(x_test,y_test,verbose=2)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
# ...
